# %% [markdown]
# ## <a href="https://colab.research.google.com/github/LMU-CMSI-1010/lab-notebooks-original/blob/main/Lab11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 11 Turtle Fractals
# In this lab you will use Turtle graphics to write recursive functions that you can see in your notebook. First, let's get to some preliminaries...

# %% [markdown]
# ## Setup
# To use turtle graphics in a notebook, first run the following code block:

# %%
# !pip3 install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=de9cd96079d693fad69afe96721c17acd63abcd2e6d64c4e178a5e9c0f812d8a
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %% [markdown]
# Once that succeeds, run this one next to import everything in the module:

# %%
from ColabTurtle.Turtle import *

# %% [markdown]
# Once both of these have executed successfully, you can have a turtle in a Colab Jupyter notebook! Additional documentation can be found here: https://github.com/tolgaatam/ColabTurtle

# %% [markdown]
# ## Turtle Recap
# All turtle-in-notebook programs must start with `initializeTurtle()` to set things up.
#
# Here is a simple program that makes it take 100 steps forward then turns it 90 degrees counterclockwise:

# %%
initializeTurtle()

forward(100) # move 100 steps
left(90) # turn 90 degrees
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(270,400.0,150.0) translate(382.0, 132.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:white;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %% [markdown]
# ## Turtle Walk Forward—Recursively
# In the following cell, let's write a **recursive** function to make Turtle walk forward.

# %%
def walk_forward(n):
    if n == 0:
        return

    forward(1)
    walk_forward(n - 1)

# Intializing turtle and then walking forward 100
# as above. Why so slow little turtle?
initializeTurtle()
walk_forward(100)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="249.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="249.0" x2="400.0" y2="248.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="248.0" x2="400.0" y2="247.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="247.0" x2="400.0" y2="246.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="246.0" x2="400.0" y2="245.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="245.0" x2="400.0" y2="244.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="244.0" x2="400.0" y2="243.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="243.0" x2="400.0" y2="242.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="242.0" x2="400.0" y2="241.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="241.0" x2="400.0" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="240.0" x2="400.0" y2="239.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="239.0" x2="400.0" y2="238.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="238.0" x2="400.0" y2="237.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="237.0" x2="400.0" y2="236.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="236.0" x2="400.0" y2="235.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="235.0" x2="400.0" y2="234.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="234.0" x2="400.0" y2="233.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="233.0" x2="400.0" y2="232.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="232.0" x2="400.0" y2="231.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="231.0" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="230.0" x2="400.0" y2="229.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="229.0" x2="400.0" y2="228.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="228.0" x2="400.0" y2="227.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="227.0" x2="400.0" y2="226.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="226.0" x2="400.0" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="225.0" x2="400.0" y2="224.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="224.0" x2="400.0" y2="223.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="223.0" x2="400.0" y2="222.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="222.0" x2="400.0" y2="221.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="221.0" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="220.0" x2="400.0" y2="219.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="219.0" x2="400.0" y2="218.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="218.0" x2="400.0" y2="217.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="217.0" x2="400.0" y2="216.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="216.0" x2="400.0" y2="215.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="215.0" x2="400.0" y2="214.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="214.0" x2="400. ...

# %%
def draw_branch(n, branch_length=32):
    if n == 10:
        return

    forward(32 * 10)
    left(50)
    draw_branch(n - 1, 32)
    right(100)
    draw_branch(n - 1, 32)
    left(50)
    back(10 * 32)

initializeTurtle()
draw_branch(3)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="-70.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="-70.0" x2="154.866" y2="-275.692" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="154.866" y1="-275.692" x2="-160.272" y2="-220.125" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-160.272" y1="-220.125" x2="-320.272" y2="57.003" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-320.272" y1="57.003" x2="-210.826" y2="357.705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-210.826" y1="357.705" x2="89.876" y2="467.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="89.876" y1="467.151" x2="367.004" y2="307.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="367.004" y1="307.151" x2="422.571" y2="-7.987" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="422.571" y1="-7.987" x2="216.879" y2="-253.121" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="216.879" y1="-253.121" x2="-103.121" y2="-253.121" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-103.121" y1="-253.121" x2="-308.813" y2="-7.987" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-308.813" y1="-7.987" x2="-253.246" y2="307.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-253.246" y1="307.151" x2="23.882" y2="467.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="23.882" y1="467.151" x2="324.584" y2="357.705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.584" y1="357.705" x2="434.03" y2="57.003" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="434.03" y1="57.003" x2="274.03" y2="-220.125" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="274.03" y1="-220.125" x2="-41.108" y2="-275.692" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-41.108" y1="-275.692" x2="-286.242" y2="-70.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-286.242" y1="-70.0" x2="-286.242" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-286.242" y1="250.0" x2="-41.108" y2="455.692" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-41.108" y1="455.692" x2="274.03" y2="400.125" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="274.03" y1="400.125" x2="434.03" y2="122.997" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="434.03" y1="122.997" x2="324.584" y2="-177.705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.584" y1="-177.705" x2="23.882" y2="-287.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="23.882" y1="-287.151" x2="-253.246" y2="-127.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-253.246" y1="-127.151" x2="-308.813" y2="187.987" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-308.813" y1="187.987" x2="-103.121" y2="433.121" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-103.121" y1="433.121" x2="216.879" y2="433.121" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="216.879" y1="433.121" x2="422.571" y2="187.987" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="422.571" y1="187.987" x2="367.004" y2="-127.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="367.004" y1="-127.151" x2="89.876" y2="-287.151" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="89.876" y1="-287.151" x2="-210.826" y2="-177.705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-210.826" y1="-177.705" x2="-320.272" y2="122.997" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-320.272" y1="122.997" x2="-160.272" y2="400.125" stroke-linecap="round" style="stroke: ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-efa578518cc9> in <module>()
#      12
#      13 initializeTurtle()
# ---> 14 draw_branch(3)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       5     forward(32 * 10)
#       6     left(50)
# ----> 7     draw_branch(n - 1, 32)
#       8     right(100)
#       9     draw_branch(n - 1, 32)
#
# <ipython-input-7-efa578518cc9> in draw_branch(n, branch_length)
#       3         return
#       4
# ----> 5     forward(32 * 10)
#       6     left(50)
#       7     draw_branch(n - 1, 32)
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in forward(units)
#     172     ending_point = (turtle_pos[0] + units * math.cos(alpha), turtle_pos[1] + units * math.sin(alpha))
#     173
# --> 174     _moveToNewPosition(ending_point)
#     175
#     176 fd = forward # alias
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _moveToNewPosition(new_pos)
#     161
#     162     turtle_pos = new_pos
# --> 163     _updateDrawing()
#     164
#     165
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _updateDrawing()
#     143     if drawing_window == None:
#     144         raise AttributeError("Display has not been initialized yet. Call initializeTurtle() before using.")
# --> 145     time.sleep(_speedToSec(turtle_speed))
#     146     drawing_window.update(HTML(_generateSvgDrawing()))
#     147
#
# KeyboardInterrupt:

# %% [markdown]
# ## More Turtle Fractals
#
# Now it's your turn. In the following cell you will be guided through writing a recursive function to draw a Koch fractal. (Additional details on the Koch fractal can be found in the Turtles & Fractals slides PDF on Brightspace.)
#
# **TODO:** Please follow the comments to complete the function `koch_fractal`.

# %%
def koch_fractal(n, step):
    # n branch lenght ==20,
    # 5
    if n == 1:
        forward(step)
        return

        def factorial(n):
     if n == 0:
         return 1

     else:
         return n * factorial(n - 1)



def suzy = turtle.Turtle()
suzy.forward(100) # move 100 steps
suzy.left(90) # turn 60 degrees



 def suzy=turtle.Turtle(15,3)
suzy.walk_forward (100)#move 100 steps 
suzy.left(90)# turn 60 degrees
                      

#4
def suzy.right(120)# turn 60 degrees
                      

    # 5
def suzy=turtle.Turtle(15,3)
suzy.walk_forward (100)#move 100 steps 
suzy.left(90)# turn 60 degrees



    # 6
def suzy=turtle.Turtle(15,3)
suzy.walk_forward (100)#move 100 steps 
suzy.left(90)# turn 60 degrees

def turtle.mainloop 

    # END recursive case

# This brings Turtle to leftmost portion
# of screen. You do not need to change this code.
initializeTurtle()
penup()
goto(0, 200)
pendown()
right(90)

# Here you can change calls to koch_fractal to draw curves
# Remember the first argument n is how many turns you want
# Turtle to make drawing curves, and the second argument step
# is how far Turtle will walk forward.
# This function is not efficient, so try with small values of n
koch_fractal(3, 10)
# Out:
#   File "<ipython-input-10-616051e143c5>", line 9
#     if n == 0:
#               ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # Tracing Turtle Fractal
# Can you trace `koch_fractal` when `n` is 2? You can follow along drawing by hand with Turtle and labeling the function calls to create a stack diagram.

# %% [markdown]
# ***
#
# > Explain your uploaded stack diagram here.
#
# ***

# %% [markdown]
# ### Reflections
# Add a text cell below to answer the following questions:
# 1. What do you feel more confident about after completing this lab?
# I feel more confident in writing Turtle Fractal functions recursively
#
# 2. What do you feel you can use more help with after completing this
# lab?
#
# I feel like I could use more help with tracing the turtle Fractal
#
# 3. Do you have any constructive suggestions on how we can help you or improve this lab?

# %% [markdown]
# ### Save your work to GitHub
# Please save this notebook to your lab repository.
